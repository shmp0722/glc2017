# %%
import numpy as np
import pandas as pd

# %%
df  = pd.read_csv('T2.txt')

# %%
df
# Out:
#      age   VA     MD10_2        PSD  PSD_p  fovea  P1  P2  P3  P4  \
# 0     58  1.5 -14.740000  14.000000   0.01     35   5   9  -1   7
# 1     57  1.2 -13.260000  14.650000   0.01     36  24  23   0  11
# 2     58  1.2 -11.870000  13.570000   0.01     35   5  -1   6  -1
# 3     57  1.5  -9.080000  12.710000   0.01     37   4  11  13  18
# 4     67  1.0 -12.080000  10.130000   0.01     36  25  26  29  30
# 5     67  1.2  -1.620000   1.620000   0.05     37  30  28  31  30
# 6     74  0.9  -3.840000   5.760000   0.01     35  -1  -1  18  10
# 7     73  1.0  -3.890000   7.110000   0.01     35  10  -1  20   4
# 8     74  1.2  -5.540000  12.300000   0.01     38  -1  -1   1  -1
# 9     73  1.2  -5.970000  12.090000   0.01     37  -1  -1  14  -1
# 10    66  0.6 -29.350000   9.620000   0.01     27  -1  -1  -1  -1
# 11    66  0.6 -27.650000  10.700000   0.01     29  -1  -1  -1  -1
# 12    65  0.6 -28.990000   9.540000   0.01     27  -1  -1  -1  -1
# ...
